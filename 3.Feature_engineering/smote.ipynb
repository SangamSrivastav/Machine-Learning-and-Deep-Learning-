# %%
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=1000, n_redundant=0, n_features=2, n_clusters_per_class=1,
                          weights=[0.90], random_state=12)

# %%
import pandas as pd
df1 = pd.DataFrame(X, columns=['feature1', 'feature2'])
df2 = pd.DataFrame(y, columns=['target'])

final_df = pd.concat([df1,df2],axis=1)

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
final_df
# Out:
#      feature1  feature2  target
# 0   -0.762898 -0.706808       0
# 1   -1.075436 -1.051162       0
# 2   -0.610115 -0.909802       0
# 3   -2.023284 -0.428945       1
# 4   -0.812921 -1.316206       0
# ..        ...       ...     ...
# 995 -0.712495 -0.880452       0
# 996 -2.625830 -2.827891       0
# 997 -1.326439 -1.815178       0
# 998 -0.833486 -0.514647       0
# 999 -0.302876 -0.575975       0
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(final_df['feature1'],final_df['feature2'], c = final_df['target'])

# %%
pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\sanga\desktop\pythonu\venv\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\sanga\desktop\pythonu\venv\lib\site-packages (from imblearn) (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\sanga\desktop\pythonu\venv\lib\site-packages (from imbalanced-learn->imblearn) (2.2.3)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\sanga\desktop\pythonu\venv\lib\site-packages (from imbalanced-learn->imblearn) (1.15.2)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\sanga\desktop\pythonu\venv\lib\site-packages (from imbalanced-learn->imblearn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\sanga\desktop\pythonu\venv\lib\site-packages (from imbalanced-learn->imblearn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\sanga\desktop\pythonu\venv\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\sanga\desktop\pythonu\venv\lib\site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
## Transform the dataset
oversample = SMOTE()
X,y = oversample.fit_resample(final_df[['feature1','feature2']], final_df['target'])

# %%
print(X.shape)
print(y.shape)
# Out:
# (1800, 2)
# (1800,)

# %%
print(len(y[y==0]))
print(len(y[y==1]))
# Out:
# 900
# 900

# %%
df1 = pd.DataFrame(X, columns=['feature1', 'feature2'])
df2 = pd.DataFrame(y, columns=['target'])

oversample_df = pd.concat([df1,df2],axis=1)

# %%
plt.scatter(oversample_df['feature1'],oversample_df['feature2'], c = oversample_df['target'])
